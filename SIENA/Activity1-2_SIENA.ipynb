# %% [markdown]
# <h1>Installing Dependencies</h1>

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC46\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC46\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC46\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: C:\Users\LAB4-StudentPC46\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# <h1>Importing Libraries</h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# <h1>Creating DataFrame</h1>

# %%
birds = pd.read_csv("penguins.csv")

# %% [markdown]
# <h1>Calling DataFrame</h1>

# %%
birds
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# <h1>Checking Information</h1>

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %% [markdown]
# <h1>Describe the Data</h1>

# %%
birds.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
birds.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                       75%     max
# bill_length_mm       48.5    59.6
# bill_depth_mm        18.7    21.5
# flipper_length_mm   213.0   231.0
# body_mass_g        4750.0  6300.0
# year               2009.0  2009.0

# %% [markdown]
# <h1>Checking Null Values</h1>

# %%
birds.isnull()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False           False          False              False
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex   year
# 0          False  False  False
# 1          False  False  False
# ...

# %% [markdown]
# <h1>Checking the total sum of Null Values</h1>

# %%
birds.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
birds['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %% [markdown]
# <h1>Converting the Null Values</h1>

# %%
birds['bill_length_mm'] = birds['bill_length_mm'].fillna(birds['bill_length_mm'].mean())

# %%
birds['bill_depth_mm'] = birds['bill_depth_mm'].fillna(birds['bill_depth_mm'].mean())

# %%
birds['flipper_length_mm'] = birds['flipper_length_mm'].fillna(birds['flipper_length_mm'].mean())

# %%
birds['body_mass_g'] = birds['body_mass_g'].fillna(birds['body_mass_g'].mean())

# %%
birds['sex'] = birds['sex'].fillna(birds['sex'].mode()[0])

# %%
birds.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %% [markdown]
# <h1>Changing Datatype</h1>

# %%
birds['species'] = birds['species'].astype('category')
birds['sex'] = birds['sex'].astype('category')
birds['island'] = birds['island'].astype('category')

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    category
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    category
#  7   year               344 non-null    int64
# dtypes: category(3), float64(4), int64(1)
# memory usage: 15.0 KB

# %% [markdown]
# <h1>Does Gentoo lives on island Dream</h1>

# %%
birds['island']
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339        Dream
# 340        Dream
# 341        Dream
# 342        Dream
# 343        Dream
# Name: island, Length: 344, dtype: category
# Categories (3, object): ['Biscoe', 'Dream', 'Torgersen']

# %%
gentoo_dream = birds[(birds['species'] == 'Gentoo') & (birds['island'] == "Dream")]

# %%
gentoo_dream
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %% [markdown]
# <h1>Does Gentoo lives on island Biscoe</h1>

# %%
gentoo_biscoe = birds[(birds['species'] == 'Gentoo') & (birds['island'] == "Biscoe")]

# %%
gentoo_biscoe
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..      ...     ...             ...            ...                ...
# 271  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year
# 152  4500.000000  female  2007
# 153  5700.000000    male  2007
# ...

# %% [markdown]
# <h1>Does Gentoo lives on island Torgersen</h1>

# %%
gentoo_torgersen = birds[(birds['species'] == 'Gentoo') & (birds['island'] == "Torgersen")]

# %%
gentoo_torgersen
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %% [markdown]
# <h1 style='color:green'> #1 It seems that Gentoo only lives in Biscoe</h1>

# %% [markdown]
# <h1> Does Adelie lives on island Torgersen </h1>

# %%
birds['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: category
# Categories (3, object): ['Adelie', 'Chinstrap', 'Gentoo']

# %%
adelie_torgersen = birds[(birds['species'] == 'Adelie') & (birds['island'] == "Torgersen")]

# %%
adelie_torgersen
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen        39.10000       18.70000         181.000000
# 1    Adelie  Torgersen        39.50000       17.40000         186.000000
# 2    Adelie  Torgersen        40.30000       18.00000         195.000000
# 3    Adelie  Torgersen        43.92193       17.15117         200.915205
# 4    Adelie  Torgersen        36.70000       19.30000         193.000000
# 5    Adelie  Torgersen        39.30000       20.60000         190.000000
# 6    Adelie  Torgersen        38.90000       17.80000         181.000000
# 7    Adelie  Torgersen        39.20000       19.60000         195.000000
# 8    Adelie  Torgersen        34.10000       18.10000         193.000000
# 9    Adelie  Torgersen        42.00000       20.20000         190.000000
# 10   Adelie  Torgersen        37.80000       17.10000         186.000000
# 11   Adelie  Torgersen        37.80000       17.30000         180.000000
# ...

# %% [markdown]
# <h1>Does Adelie lives on island Dream</h1>

# %%
adelie_dream = birds[(birds['species'] == 'Adelie') & (birds['island'] == "Dream")]

# %%
adelie_dream
# Out:
#     species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30   Adelie  Dream            39.5           16.7              178.0
# 31   Adelie  Dream            37.2           18.1              178.0
# 32   Adelie  Dream            39.5           17.8              188.0
# 33   Adelie  Dream            40.9           18.9              184.0
# 34   Adelie  Dream            36.4           17.0              195.0
# 35   Adelie  Dream            39.2           21.1              196.0
# 36   Adelie  Dream            38.8           20.0              190.0
# 37   Adelie  Dream            42.2           18.5              180.0
# 38   Adelie  Dream            37.6           19.3              181.0
# 39   Adelie  Dream            39.8           19.1              184.0
# 40   Adelie  Dream            36.5           18.0              182.0
# 41   Adelie  Dream            40.8           18.4              195.0
# 42   Adelie  Dream            36.0           18.5              186.0
# ...

# %% [markdown]
# <h1>Does Adelie lives on island Biscoe</h1>

# %%
adelie_biscoe = birds[(birds['species'] == 'Adelie') & (birds['island'] == "Biscoe")]

# %%
adelie_biscoe
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20   Adelie  Biscoe            37.8           18.3              174.0
# 21   Adelie  Biscoe            37.7           18.7              180.0
# 22   Adelie  Biscoe            35.9           19.2              189.0
# 23   Adelie  Biscoe            38.2           18.1              185.0
# 24   Adelie  Biscoe            38.8           17.2              180.0
# 25   Adelie  Biscoe            35.3           18.9              187.0
# 26   Adelie  Biscoe            40.6           18.6              183.0
# 27   Adelie  Biscoe            40.5           17.9              187.0
# 28   Adelie  Biscoe            37.9           18.6              172.0
# 29   Adelie  Biscoe            40.5           18.9              180.0
# 50   Adelie  Biscoe            39.6           17.7              186.0
# 51   Adelie  Biscoe            40.1           18.9              188.0
# ...

# %% [markdown]
# <h1 style='color:green'> #2 It seems that Adelie Lives in all 3 Islands</h1>

# %% [markdown]
# <h1>Does Chinstrap lives on island Biscoe</h1>

# %%
chinstrap_biscoe = birds[(birds['species'] == 'Chinstrap') & (birds['island'] == "Biscoe")]

# %%
chinstrap_biscoe
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %% [markdown]
# <h1>Does Chinstrap lives on island Dream </h1>

# %%
chinstrap_dream = birds[(birds['species'] == 'Chinstrap') & (birds['island'] == "Dream")]

# %%
chinstrap_dream
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %% [markdown]
# <h1>Does Chinstrap lives in island Torgersen </h1>

# %%
chinstrap_torgersen = birds[(birds['species'] == 'Chinstrap') & (birds['island'] == "Torgersen")]

# %%
chinstrap_torgersen
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %% [markdown]
# <h1 style='color:green'> #3 It seems that Chinstrap only lives on Bicoe and Dream</h1>

# %% [markdown]
# <h1 style='color:green'> #4 Average Weight of Gentoo </h1>

# %%
birds['wkilo'] = birds['body_mass_g'] / 1000

# %%
gentoo_avg_weight = np.round(birds[birds['species'] == 'Gentoo']['wkilo'].mean(),1)

# %%
gentoo_avg_weight
# Out:
# np.float64(5.1)

# %% [markdown]
# <h1 style='color:green'> #5 Average Weight of Adelie </h1>

# %%
adelie_avg_weight = np.round(birds[birds['species'] == 'Adelie']['wkilo'].mean(),1)

# %%
adelie_avg_weight
# Out:
# np.float64(3.7)

# %% [markdown]
# <h1 style='color:green'> #6 Average Weight of Chinstrap </h1>

# %%
chinstrap_avg_weight = np.round(birds[birds['species'] == 'Chinstrap']['wkilo'].mean(),1)

# %%
chinstrap_avg_weight
# Out:
# np.float64(3.7)

# %% [markdown]
# <h1 style='color:green'> #7 What species is the Heaviest. </h1>

# %%
heaviest_species = np.round(birds.groupby(['island','species'])['wkilo'].mean(),1)
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_18840\3349110742.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   heaviest_species = np.round(birds.groupby(['island','species'])['wkilo'].mean(),1)

# %%
heaviest_species.unstack()
# Out:
# species    Adelie  Chinstrap  Gentoo
# island
# Biscoe        3.7        NaN     5.1
# Dream         3.7        3.7     NaN
# Torgersen     3.7        NaN     NaN

# %% [markdown]
# <h1 style="color:green"> Gentoo is the Heaviest Species </h1>

# %% [markdown]
# <h1 style="color:green"> #8 What is the Heaviest Male in Year 2007-2009 </h1>

# %%
birds_agg3 = birds.groupby(['species','island','sex','year']).size()
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_18840\358138408.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg3 = birds.groupby(['species','island','sex','year']).size()

# %%
birds_agg3.unstack()
# Out:
# year                        2007  2008  2009
# species   island    sex
# Adelie    Biscoe    female     5     9     8
#                     male       5     9     8
#           Dream     female     9     8    10
#                     male      11     8    10
#           Torgersen female     8     8     8
#                     male      12     8     8
# Chinstrap Biscoe    female     0     0     0
#                     male       0     0     0
#           Dream     female    13     9    12
#                     male      13     9    12
#           Torgersen female     0     0     0
#                     male       0     0     0
# Gentoo    Biscoe    female    16    22    20
#                     male      18    24    24
#           Dream     female     0     0     0
#                     male       0     0     0
#           Torgersen female     0     0     0
#                     male       0     0     0

# %% [markdown]
# <h1 style='color:green'> #9 Sex Weight Comparison of Adelie, Male is heavier than Female </h1>
# <h1 style='color:green'> #10 Sex Weight Comparison of Chinstrap, Male is heavier than Female </h1>
# <h1 style='color:green'> #11 Sex Weight Comparison of Gentoo, Male is heavier than Female </h1>
# <h1 style='color:green'> We see that Male is heavier than Female </h1>

# %%
birds_agg4 = np.round(birds.groupby(['species','sex'])['wkilo'].mean(),1)
# Out:
# C:\Users\LAB4-StudentPC46\AppData\Local\Temp\ipykernel_18840\203187124.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   birds_agg4 = np.round(birds.groupby(['species','sex'])['wkilo'].mean(),1)

# %%
birds_agg4.unstack()
# Out:
# sex        female  male
# species
# Adelie        3.4   4.0
# Chinstrap     3.5   3.9
# Gentoo        4.7   5.4

# %% [markdown]
# <h1 style='color:green'> #12 Does Bill Depth has Correlation with Flipper Length </h1>

# %%
bill_flipper_corr = birds['bill_depth_mm'].corr(birds['flipper_length_mm'])

# %%
bill_flipper_corr
# Out:
# np.float64(-0.5838512164654122)

# %% [markdown]
# <h1 style='color:green'> Bill Depth has no Correlation with Flipper Length </h1>

# %% [markdown]
# <h1 style='color:green'> #13 Does Body Mass has Correlation with Bill Length </h1>

# %%
bill_body_corr = birds['body_mass_g'].corr(birds['bill_length_mm'])

# %%
bill_body_corr
# Out:
# np.float64(0.5951098244376305)

# %% [markdown]
# <h1 style='color:green'> Body Mass has Correlation with Bill Length </h1>

# %% [markdown]
# <h1 style='color:green'> #14 Does the Body Mass Affects the Sex of the Species </h1>

# %%
body_sex_corr = birds['body_mass_g'].corr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 body_sex_corr = birds['body_mass_g'].corr()
#
# TypeError: Series.corr() missing 1 required positional argument: 'other'

# %%
birds.info()
